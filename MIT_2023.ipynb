# %% [markdown]
# # Credit card fraud detector

# %% [markdown]
# ## Investigate and process the data

# %% [markdown]
# Let's start by downloading and reading in the credit card fraud data set.

# %%
# %%bash
# wget https://s3-us-west-2.amazonaws.com/sagemaker-e2e-solutions/fraud-detection/creditcardfraud.zip
# unzip creditcardfraud.zip
# Out:
# --2023-12-06 14:25:19--  https://s3-us-west-2.amazonaws.com/sagemaker-e2e-solutions/fraud-detection/creditcardfraud.zip
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.197.56, 52.92.225.216, 52.92.250.160, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.197.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip’
#
#      0K .......... .......... .......... .......... ..........  0%  851K 79s
#     50K .......... .......... .......... .......... ..........  0%  854K 79s
#    100K .......... .......... .......... .......... ..........  0%  851K 79s
#    150K .......... .......... .......... .......... ..........  0%  144M 59s
#    200K .......... .......... .......... .......... ..........  0%  864K 63s
#    250K .......... .......... .......... .......... ..........  0% 98.2M 53s
#    300K .......... .......... .......... .......... ..........  0% 72.2M 45s
#    350K .......... .......... .......... .......... ..........  0%  244M 40s
#    400K .......... .......... .......... .......... ..........  0%  223M 35s
#    450K .......... .......... .......... .......... ..........  0%  875K 39s
#    500K .......... .......... .......... .......... ..........  0%  158M 36s
#    550K .......... .......... .......... .......... ..........  0%  217M 33s
#    600K .......... .......... .......... .......... ..........  0% 99.6M 30s
#    650K .......... .......... .......... .......... ..........  1%  196M 28s
#    700K .......... .......... .......... .......... ..........  1%  206M 26s
#    750K .......... .......... .......... .......... ..........  1%  219M 25s
#    800K .......... .......... .......... .......... ..........  1%  885K 28s
#    850K .......... .......... .......... .......... ..........  1%  156M 26s
#    900K .......... .......... .......... .......... ..........  1%  198M 25s
#    950K .......... .......... .......... .......... ..........  1%  197M 23s
#   1000K .......... .......... .......... .......... ..........  1%  195M 22s
#   1050K .......... .......... .......... .......... ..........  1%  202M 21s
#   1100K .......... .......... .......... .......... ..........  1%  178M 20s
#   1150K .......... .......... .......... .......... ..........  1%  219M 20s
#   1200K .......... .......... .......... .......... ..........  1%  219M 19s
#   1250K .......... .......... .......... .......... ..........  1%  207M 18s
#   1300K .......... .......... .......... .......... ..........  1%  206M 17s
#   1350K .......... .......... .......... .......... ..........  2%  216M 17s
#   1400K .......... .......... .......... .......... ..........  2%  144M 16s
#   1450K .......... .......... .......... .......... ..........  2%  201M 16s
#   1500K .......... .......... .......... .......... ..........  2%  215M 15s
#   1550K .......... .......... .......... .......... ..........  2%  217M 15s
#   1600K .......... .......... .......... .......... ..........  2%  249M 14s
#   1650K .......... .......... .......... .......... ..........  2%  916K 16s
#   1700K .......... .......... .......... .......... ..........  2%  177M 15s
#   1750K .......... .......... .......... .......... ..........  2%  218M 15s
#   1800K .......... .......... .......... .......... ..........  2%  231M 15s
#   1850K .......... .......... .......... .......... ..........  2%  215M 14s
#   1900K .......... .......... .......... .......... ..........  2%  270M 14s
#   1950K .......... .......... .......... .......... ..........  2%  155M 13s
#   2000K .......... .......... .......... .......... ..........  3%  259M 13s
#   2050K .......... .......... .......... .......... ..........  3%  214M 13s
#   2100K .......... .......... .......... .......... ..........  3%  249M 13s
#   2150K .......... .......... .......... .......... ..........  3%  246M 12s
#   2200K .......... .......... .......... .......... ..........  3%  242M 12s
#   2250K .......... .......... .......... .......... ..........  3%  218M 12s
#   2300K .......... .......... .......... .......... ..........  3%  238M 11s
#   2350K .......... .......... .......... .......... ..........  3%  219M 11s
#   2400K .......... .......... .......... .......... ..........  3%  159M 11s
#   2450K .......... .......... .......... .......... ..........  3%  184M 11s
#   2500K .......... .......... .......... .......... ..........  3%  260M 11s
#   2550K .......... .......... .......... .......... ..........  3%  248M 10s
#   2600K .......... .......... .......... .......... ..........  3%  250M 10s
#   2650K .......... .......... .......... .......... ..........  3%  154M 10s
#   2700K .......... .......... .......... .......... ..........  4%  242M 10s
#   2750K .......... .......... .......... .......... ..........  4%  255M 10s
#   2800K .......... .......... .......... .......... ..........  4%  274M 9s
#   2850K .......... .......... .......... .......... ..........  4%  174M 9s
#   2900K .......... .......... .......... .......... ..........  4%  232M 9s
#   2950K .......... .......... .......... .......... ..........  4%  263M 9s
#   3000K .......... .......... .......... .......... ..........  4%  260M 9s
#   3050K .......... .......... .......... .......... ..........  4%  235M 9s
#   3100K .......... .......... .......... .......... ..........  4%  234M 9s
#   3150K .......... .......... .......... .......... ..........  4%  170M 8s
#   3200K .......... .......... .......... .......... ..........  4%  963K 9s
#   3250K .......... .......... .......... .......... ..........  4%  200M 9s
#   3300K .......... .......... .......... .......... ..........  4%  201M 9s
#   3350K .......... .......... .......... .......... ..........  5%  245M 9s
#   3400K .......... .......... .......... .......... ..........  5%  233M 9s
#   3450K .......... .......... .......... .......... ..........  5%  234M 9s
#   3500K .......... .......... .......... .......... ..........  5%  244M 8s
#   3550K .......... .......... .......... .......... ..........  5%  214M 8s
#   3600K .......... .......... .......... .......... ..........  5%  269M 8s
#   3650K .......... .......... .......... .......... ..........  5%  200M 8s
#   3700K .......... .......... .......... .......... ..........  5%  245M 8s
#   3750K .......... .......... .......... .......... ..........  5%  254M 8s
#   3800K .......... .......... .......... .......... ..........  5%  239M 8s
#   3850K .......... .......... .......... .......... ..........  5%  216M 8s
#   3900K .......... .......... .......... .......... ..........  5%  243M 8s
#   3950K .......... .......... .......... .......... ..........  5%  231M 7s
#   4000K .......... .......... .......... .......... ..........  5%  248M 7s
#   4050K .......... .......... .......... .......... ..........  6%  200M 7s
#   4100K .......... .......... .......... .......... ..........  6%  254M 7s
#   4150K .......... .......... .......... .......... ..........  6%  247M 7s
#   4200K .......... .......... .......... .......... ..........  6%  260M 7s
#   4250K .......... .......... .......... .......... ..........  6%  147M 7s
#   4300K .......... .......... .......... .......... ..........  6%  233M 7s
#   4350K .......... .......... .......... .......... ..........  6%  179M 7s
#   4400K .......... .......... .......... .......... ..........  6%  187M 7s
#   4450K .......... .......... .......... .......... ..........  6%  190M 7s
#   4500K .......... .......... .......... .......... ..........  6%  177M 7s
#   4550K .......... .......... .......... .......... ..........  6%  191M 6s
#   4600K .......... .......... .......... .......... ..........  6%  250M 6s
#   4650K .......... .......... .......... .......... ..........  6% 68.6M 6s
#   4700K .......... .......... .......... .......... ..........  7%  975K 7s
#   4750K .......... .......... .......... .......... ..........  7% 81.6M 7s
#   4800K .......... .......... .......... .......... ..........  7%  230M 7s
#   4850K .......... .......... .......... .......... ..........  7%  186M 7s
#   4900K .......... .......... .......... .......... ..........  7%  230M 7s
#   4950K .......... .......... .......... .......... ..........  7%  234M 7s
#   5000K .......... .......... .......... .......... ..........  7%  238M 7s
#   5050K .......... .......... .......... .......... ..........  7%  228M 6s
#   5100K .......... .......... .......... .......... ..........  7%  198M 6s
#   5150K .......... .......... .......... .......... ..........  7%  267M 6s
#   5200K .......... .......... .......... .......... ..........  7%  260M 6s
#   5250K .......... .......... .......... .......... ..........  7%  208M 6s
#   5300K .......... .......... .......... .......... ..........  7%  267M 6s
#   5350K .......... .......... .......... .......... ..........  7%  249M 6s
#   5400K .......... .......... .......... .......... ..........  8%  251M 6s
#   5450K .......... .......... .......... .......... ..........  8%  215M 6s
#   5500K .......... .......... .......... .......... ..........  8%  262M 6s
#   5550K .......... .......... .......... .......... ..........  8%  164M 6s
#   5600K .......... .......... .......... .......... ..........  8%  239M 6s
#   5650K .......... .......... .......... .......... ..........  8%  156M 6s
#   5700K .......... .......... .......... .......... ..........  8%  216M 6s
#   5750K .......... .......... .......... .......... ..........  8%  254M 6s
#   5800K .......... .......... .......... .......... ..........  8%  273M 6s
#   5850K .......... .......... .......... .......... ..........  8%  161M 6s
#   5900K .......... .......... .......... .......... ..........  8%  251M 6s
#   5950K .......... .......... .......... .......... ..........  8%  180M 5s
#   6000K .......... .......... .......... .......... ..........  8%  164M 5s
#   6050K .......... .......... .......... .......... ..........  9%  207M 5s
#   6100K .......... .......... .......... .......... ..........  9% 75.3M 5s
#   6150K .......... .......... .......... .......... ..........  9%  229M 5s
#   6200K .......... .......... .......... .......... ..........  9% 74.4M 5s
#   6250K .......... .......... .......... .......... ..........  9%  977K 6s
#   6300K .......... .......... .......... .......... ..........  9%  112M 6s
#   6350K .......... .......... .......... .......... ..........  9%  220M 6s
#   6400K .......... .......... .......... .......... ..........  9%  253M 6s
#   6450K .......... .......... .......... .......... ..........  9%  197M 6s
#   6500K .......... .......... .......... .......... ..........  9%  270M 5s
#   6550K .......... .......... .......... .......... ..........  9%  246M 5s
#   6600K .......... .......... .......... .......... ..........  9%  256M 5s
#   6650K .......... .......... .......... .......... ..........  9%  199M 5s
#   6700K .......... .......... .......... .......... ..........  9%  261M 5s
#   6750K .......... .......... .......... .......... .......... 10%  270M 5s
#   6800K .......... .......... .......... .......... .......... 10%  254M 5s
#   6850K .......... .......... .......... .......... .......... 10%  217M 5s
#   6900K .......... .......... .......... .......... .......... 10%  222M 5s
#   6950K .......... .......... .......... .......... .......... 10%  235M 5s
#   7000K .......... .......... .......... .......... .......... 10%  251M 5s
#   7050K .......... .......... .......... .......... .......... 10%  250M 5s
#   7100K .......... .......... .......... .......... .......... 10%  211M 5s
#   7150K .......... .......... .......... .......... .......... 10%  225M 5s
#   7200K .......... .......... .......... .......... .......... 10%  261M 5s
#   7250K .......... .......... .......... .......... .......... 10%  129M 5s
#   7300K .......... .......... .......... .......... .......... 10%  266M 5s
#   7350K .......... .......... .......... .......... .......... 10%  251M 5s
#   7400K .......... .......... .......... .......... .......... 11%  252M 5s
#   7450K .......... .......... .......... .......... .......... 11%  230M 5s
#   7500K .......... .......... .......... .......... .......... 11%  185M 5s
#   7550K .......... .......... .......... .......... .......... 11%  248M 5s
#   7600K .......... .......... .......... .......... .......... 11%  183M 5s
#   7650K .......... .......... .......... .......... .......... 11%  160M 5s
#   7700K .......... .......... .......... .......... .......... 11% 53.6M 5s
#   7750K .......... .......... .......... .......... .......... 11%  249M 5s
#   7800K .......... .......... .......... .......... .......... 11%  969K 5s
#   7850K .......... .......... .......... .......... .......... 11%  209M 5s
#   7900K .......... .......... .......... .......... .......... 11%  253M 5s
#   7950K .......... .......... .......... .......... .......... 11%  280M 5s
#   8000K .......... .......... .......... .......... .......... 11%  274M 5s
#   8050K .......... .......... .......... .......... .......... 11%  202M 5s
#   8100K .......... .......... .......... .......... .......... 12%  233M 5s
#   8150K .......... .......... .......... .......... .......... 12%  257M 5s
#   8200K .......... .......... .......... .......... .......... 12%  250M 5s
#   8250K .......... .......... .......... .......... .......... 12%  231M 5s
#   8300K .......... .......... .......... .......... .......... 12%  230M 5s
#   8350K .......... .......... .......... .......... .......... 12%  221M 5s
#   8400K .......... .......... .......... .......... .......... 12%  169M 5s
#   8450K .......... .......... .......... .......... .......... 12%  209M 4s
#   8500K .......... .......... .......... .......... .......... 12%  248M 4s
#   8550K .......... .......... .......... .......... .......... 12%  257M 4s
#   8600K .......... .......... .......... .......... .......... 12%  256M 4s
#   8650K .......... .......... .......... .......... .......... 12%  218M 4s
#   8700K .......... .......... .......... .......... .......... 12%  224M 4s
#   8750K .......... .......... .......... .......... .......... 13%  259M 4s
#   8800K .......... .......... .......... .......... .......... 13%  136M 4s
#   8850K .......... .......... .......... .......... .......... 13%  196M 4s
#   8900K .......... .......... .......... .......... .......... 13%  240M 4s
#   8950K .......... .......... .......... .......... .......... 13%  176M 4s
#   9000K .......... .......... .......... .......... .......... 13%  254M 4s
#   9050K .......... .......... .......... .......... .......... 13%  247M 4s
#   9100K .......... .......... .......... .......... .......... 13%  254M 4s
#   9150K .......... .......... .......... .......... .......... 13%  267M 4s
#   9200K .......... .......... .......... .......... .......... 13%  263M 4s
#   9250K .......... .......... .......... .......... .......... 13%  210M 4s
#   9300K .......... .......... .......... .......... .......... 13%  268M 4s
#   9350K .......... .......... .......... .......... .......... 13%  957K 4s
#   9400K .......... .......... .......... .......... .......... 13%  156M 4s
#   9450K .......... .......... .......... .......... .......... 14%  130M 4s
#   9500K .......... .......... .......... .......... .......... 14%  239M 4s
#   9550K .......... .......... .......... .......... .......... 14%  224M 4s
#   9600K .......... .......... .......... .......... .......... 14%  187M 4s
#   9650K .......... .......... .......... .......... .......... 14%  209M 4s
#   9700K .......... .......... .......... .......... .......... 14%  275M 4s
#   9750K .......... .......... .......... .......... .......... 14%  238M 4s
#   9800K .......... .......... .......... .......... .......... 14%  241M 4s
#   9850K .......... .......... .......... .......... .......... 14%  151M 4s
#   9900K .......... .......... .......... .......... .......... 14%  247M 4s
#   9950K .......... .......... .......... .......... .......... 14%  258M 4s
#  10000K .......... .......... .......... .......... .......... 14%  250M 4s
#  10050K .......... .......... .......... .......... .......... 14%  212M 4s
#  10100K .......... .......... .......... .......... .......... 15%  220M 4s
#  10150K .......... .......... .......... .......... .......... 15%  244M 4s
#  10200K .......... .......... .......... .......... .......... 15%  237M 4s
#  10250K .......... .......... .......... .......... .......... 15%  221M 4s
#  10300K .......... .......... .......... .......... .......... 15%  232M 4s
#  10350K .......... .......... .......... .......... .......... 15%  250M 4s
#  10400K .......... .......... .......... .......... .......... 15%  252M 4s
#  10450K .......... .......... .......... .......... .......... 15%  203M 4s
#  10500K .......... .......... .......... .......... .......... 15%  233M 4s
#  10550K .......... .......... .......... .......... .......... 15%  245M 4s
#  10600K .......... .......... .......... .......... .......... 15%  241M 4s
#  10650K .......... .......... .......... .......... .......... 15%  222M 4s
#  10700K .......... .......... .......... .......... .......... 15%  248M 4s
#  10750K .......... .......... .......... .......... .......... 15%  174M 4s
#  10800K .......... .......... .......... .......... .......... 16%  175M 4s
#  10850K .......... .......... .......... .......... .......... 16%  183M 4s
#  10900K .......... .......... .......... .......... .......... 16%  960K 4s
#  10950K .......... .......... .......... .......... .......... 16%  161M 4s
#  11000K .......... .......... .......... .......... .......... 16%  117M 4s
#  11050K .......... .......... .......... .......... .......... 16%  219M 4s
#  11100K .......... .......... .......... .......... .......... 16%  272M 4s
#  11150K .......... .......... .......... .......... .......... 16%  236M 4s
#  11200K .......... .......... .......... .......... .......... 16%  262M 4s
#  11250K .......... .......... .......... .......... .......... 16%  196M 4s
#  11300K .......... .......... .......... .......... .......... 16%  219M 4s
#  11350K .......... .......... .......... .......... .......... 16%  214M 4s
#  11400K .......... .......... .......... .......... .......... 16%  170M 4s
#  11450K .......... .......... .......... .......... .......... 17%  216M 4s
#  11500K .......... .......... .......... .......... .......... 17%  253M 4s
#  11550K .......... .......... .......... .......... .......... 17%  268M 4s
#  11600K .......... .......... .......... .......... .......... 17%  235M 4s
#  11650K .......... .......... .......... .......... .......... 17%  196M 4s
#  11700K .......... .......... .......... .......... .......... 17%  271M 4s
#  11750K .......... .......... .......... .......... .......... 17%  215M 4s
#  11800K .......... .......... .......... .......... .......... 17%  266M 4s
#  11850K .......... .......... .......... .......... .......... 17%  239M 4s
#  11900K .......... .......... .......... .......... .......... 17%  233M 4s
#  11950K .......... .......... .......... .......... .......... 17%  254M 4s
#  12000K .......... .......... .......... .......... .......... 17%  262M 4s
#  12050K .......... .......... .......... .......... .......... 17%  222M 4s
#  12100K .......... .......... .......... .......... .......... 17%  247M 4s
#  12150K .......... .......... .......... .......... .......... 18%  270M 3s
#  12200K .......... .......... .......... .......... .......... 18%  262M 3s
#  12250K .......... .......... .......... .......... .......... 18%  202M 3s
#  12300K .......... .......... .......... .......... .......... 18%  163M 3s
#  12350K .......... .......... .......... .......... .......... 18%  255M 3s
#  12400K .......... .......... .......... .......... .......... 18%  184M 3s
#  12450K .......... .......... .......... .......... .......... 18%  954K 4s
#  12500K .......... .......... .......... .......... .......... 18%  225M 4s
#  12550K .......... .......... .......... .......... .......... 18%  143M 4s
#  12600K .......... .......... .......... .......... .......... 18%  243M 4s
#  12650K .......... .......... .......... .......... .......... 18%  228M 4s
#  12700K .......... .......... .......... .......... .......... 18%  206M 4s
#  12750K .......... .......... .......... .......... .......... 18%  240M 4s
#  12800K .......... .......... .......... .......... .......... 19%  260M 4s
#  12850K .......... .......... .......... .......... .......... 19%  198M 3s
#  12900K .......... .......... .......... .......... .......... 19%  252M 3s
#  12950K .......... .......... .......... .......... .......... 19%  153M 3s
#  13000K .......... .......... .......... .......... .......... 19%  238M 3s
#  13050K .......... .......... .......... .......... .......... 19%  217M 3s
#  13100K .......... .......... .......... .......... .......... 19%  241M 3s
#  13150K .......... .......... .......... .......... .......... 19%  230M 3s
#  13200K .......... .......... .......... .......... .......... 19%  161M 3s
#  13250K .......... .......... .......... .......... .......... 19%  214M 3s
#  13300K .......... .......... .......... .......... .......... 19%  250M 3s
#  13350K .......... .......... .......... .......... .......... 19%  249M 3s
#  13400K .......... .......... .......... .......... .......... 19%  255M 3s
#  13450K .......... .......... .......... .......... .......... 19%  173M 3s
#  13500K .......... .......... .......... .......... .......... 20%  240M 3s
#  13550K .......... .......... .......... .......... .......... 20%  265M 3s
#  13600K .......... .......... .......... .......... .......... 20%  152M 3s
#  13650K .......... .......... .......... .......... .......... 20%  179M 3s
#  13700K .......... .......... .......... .......... .......... 20%  199M 3s
#  13750K .......... .......... .......... .......... .......... 20%  240M 3s
#  13800K .......... .......... .......... .......... .......... 20% 76.1M 3s
#  13850K .......... .......... .......... .......... .......... 20%  228M 3s
#  13900K .......... .......... .......... .......... .......... 20% 72.8M 3s
#  13950K .......... .......... .......... .......... .......... 20% 1.00M 3s
#  14000K .......... .......... .......... .......... .......... 20% 18.9M 3s
#  14050K .......... .......... .......... .......... .......... 20%  133M 3s
#  14100K .......... .......... .......... .......... .......... 20%  254M 3s
#  14150K .......... .......... .......... .......... .......... 21%  230M 3s
#  14200K .......... .......... .......... .......... .......... 21%  142M 3s
#  14250K .......... .......... .......... .......... .......... 21%  210M 3s
#  14300K .......... .......... .......... .......... .......... 21%  257M 3s
#  14350K .......... .......... .......... .......... .......... 21%  215M 3s
#  14400K .......... .......... .......... .......... .......... 21%  234M 3s
#  14450K .......... .......... .......... .......... .......... 21%  217M 3s
#  14500K .......... .......... .......... .......... .......... 21%  248M 3s
#  14550K .......... .......... .......... .......... .......... 21%  241M 3s
#  14600K .......... .......... .......... .......... .......... 21%  258M 3s
#  14650K .......... .......... .......... .......... .......... 21%  227M 3s
#  14700K .......... .......... .......... .......... .......... 21%  251M 3s
#  14750K .......... .......... .......... .......... .......... 21%  258M 3s
#  14800K .......... .......... .......... .......... .......... 21%  235M 3s
#  14850K .......... .......... .......... .......... .......... 22%  222M 3s
#  14900K .......... .......... .......... .......... .......... 22%  271M 3s
#  14950K .......... .......... .......... .......... .......... 22% 5.34M 3s
#  15000K .......... .......... .......... .......... .......... 22%  192M 3s
#  15050K .......... .......... .......... .......... .......... 22%  243M 3s
#  15100K .......... .......... .......... .......... .......... 22%  274M 3s
#  15150K .......... .......... .......... .......... .......... 22%  272M 3s
#  15200K .......... .......... .......... .......... .......... 22%  267M 3s
#  15250K .......... .......... .......... .......... .......... 22%  229M 3s
#  15300K .......... .......... .......... .......... .......... 22%  262M 3s
#  15350K .......... .......... .......... .......... .......... 22%  269M 3s
#  15400K .......... .......... .......... .......... .......... 22%  260M 3s
#  15450K .......... .......... .......... .......... .......... 22%  242M 3s
#  15500K .......... .......... .......... .......... .......... 23% 1.12M 3s
#  15550K .......... .......... .......... .......... .......... 23%  104M 3s
#  15600K .......... .......... .......... .......... .......... 23%  137M 3s
#  15650K .......... .......... .......... .......... .......... 23% 93.2M 3s
#  15700K .......... .......... .......... .......... .......... 23% 96.9M 3s
#  15750K .......... .......... .......... .......... .......... 23%  135M 3s
#  15800K .......... .......... .......... .......... .......... 23%  135M 3s
#  15850K .......... .......... .......... .......... .......... 23% 83.9M 3s
#  15900K .......... .......... .......... .......... .......... 23%  111M 3s
#  15950K .......... .......... .......... .......... .......... 23%  261M 3s
#  16000K .......... .......... .......... .......... .......... 23%  274M 3s
#  16050K .......... .......... .......... .......... .......... 23%  232M 3s
#  16100K .......... .......... .......... .......... .......... 23%  274M 3s
#  16150K .......... .......... .......... .......... .......... 23%  275M 3s
#  16200K .......... .......... .......... .......... .......... 24%  275M 3s
#  16250K .......... .......... .......... .......... .......... 24%  248M 3s
#  16300K .......... .......... .......... .......... .......... 24%  263M 3s
#  16350K .......... .......... .......... .......... .......... 24%  266M 3s
#  16400K .......... .......... .......... .......... .......... 24%  231M 3s
#  16450K .......... .......... .......... .......... .......... 24% 7.10M 3s
#  16500K .......... .......... .......... .......... .......... 24%  196M 3s
#  16550K .......... .......... .......... .......... .......... 24%  117M 3s
#  16600K .......... .......... .......... .......... .......... 24%  131M 3s
#  16650K .......... .......... .......... .......... .......... 24% 96.9M 3s
#  16700K .......... .......... .......... .......... .......... 24%  106M 3s
#  16750K .......... .......... .......... .......... .......... 24%  269M 3s
#  16800K .......... .......... .......... .......... .......... 24%  278M 3s
#  16850K .......... .......... .......... .......... .......... 25%  230M 3s
#  16900K .......... .......... .......... .......... .......... 25%  272M 3s
#  16950K .......... .......... .......... .......... .......... 25%  276M 3s
#  17000K .......... .......... .......... .......... .......... 25%  281M 3s
#  17050K .......... .......... .......... .......... .......... 25% 1.13M 3s
#  17100K .......... .......... .......... .......... .......... 25%  130M 3s
#  17150K .......... .......... .......... .......... .......... 25%  181M 3s
#  17200K .......... .......... .......... .......... .......... 25%  144M 3s
#  17250K .......... .......... .......... .......... .......... 25% 88.3M 3s
#  17300K .......... .......... .......... .......... .......... 25%  135M 3s
#  17350K .......... .......... .......... .......... .......... 25%  165M 3s
#  17400K .......... .......... .......... .......... .......... 25%  221M 3s
#  17450K .......... .......... .......... .......... .......... 25%  125M 3s
#  17500K .......... .......... .......... .......... .......... 25%  107M 3s
#  17550K .......... .......... .......... .......... .......... 26%  169M 3s
#  17600K .......... .......... .......... .......... .......... 26%  263M 3s
#  17650K .......... .......... .......... .......... .......... 26%  225M 3s
#  17700K .......... .......... .......... .......... .......... 26%  207M 3s
#  17750K .......... .......... .......... .......... .......... 26%  248M 3s
#  17800K .......... .......... .......... .......... .......... 26%  284M 3s
#  17850K .......... .......... .......... .......... .......... 26%  244M 3s
#  17900K .......... .......... .......... .......... .......... 26%  252M 3s
#  17950K .......... .......... .......... .......... .......... 26%  281M 3s
#  18000K .......... .......... .......... .......... .......... 26% 5.64M 3s
#  18050K .......... .......... .......... .......... .......... 26% 69.5M 3s
#  18100K .......... .......... .......... .......... .......... 26%  215M 3s
#  18150K .......... .......... .......... .......... .......... 26%  246M 3s
#  18200K .......... .......... .......... .......... .......... 27%  261M 3s
#  18250K .......... .......... .......... .......... .......... 27%  230M 3s
#  18300K .......... .......... .......... .......... .......... 27%  252M 3s
#  18350K .......... .......... .......... .......... .......... 27%  263M 3s
#  18400K .......... .......... .......... .......... .......... 27%  255M 3s
#  18450K .......... .......... .......... .......... .......... 27% 17.3M 3s
#  18500K .......... .......... .......... .......... .......... 27%  252M 3s
#  18550K .......... .......... .......... .......... .......... 27%  241M 3s
#  18600K .......... .......... .......... .......... .......... 27% 1.23M 3s
#  18650K .......... .......... .......... .......... .......... 27%  191M 3s
#  18700K .......... .......... .......... .......... .......... 27%  255M 3s
#  18750K .......... .......... .......... .......... .......... 27%  220M 3s
#  18800K .......... .......... .......... .......... .......... 27%  119M 3s
#  18850K .......... .......... .......... .......... .......... 27%  210M 3s
#  18900K .......... .......... .......... .......... .......... 28%  248M 3s
#  18950K .......... .......... .......... .......... .......... 28%  249M 3s
#  19000K .......... .......... .......... .......... .......... 28%  248M 3s
#  19050K .......... .......... .......... .......... .......... 28%  223M 3s
#  19100K .......... .......... .......... .......... .......... 28% 31.6M 3s
#  19150K .......... .......... .......... .......... .......... 28%  175M 3s
#  19200K .......... .......... .......... .......... .......... 28%  217M 3s
#  19250K .......... .......... .......... .......... .......... 28%  216M 3s
#  19300K .......... .......... .......... .......... .......... 28%  267M 3s
#  19350K .......... .......... .......... .......... .......... 28%  245M 3s
#  19400K .......... .......... .......... .......... .......... 28%  259M 3s
#  19450K .......... .......... .......... .......... .......... 28%  158M 3s
#  19500K .......... .......... .......... .......... .......... 28% 7.65M 3s
#  19550K .......... .......... .......... .......... .......... 29% 52.3M 3s
#  19600K .......... .......... .......... .......... .......... 29%  130M 3s
#  19650K .......... .......... .......... .......... .......... 29% 95.6M 3s
#  19700K .......... .......... .......... .......... .......... 29%  109M 3s
#  19750K .......... .......... .......... .......... .......... 29%  262M 3s
#  19800K .......... .......... .......... .......... .......... 29%  265M 3s
#  19850K .......... .......... .......... .......... .......... 29%  248M 3s
#  19900K .......... .......... .......... .......... .......... 29%  156M 3s
#  19950K .......... .......... .......... .......... .......... 29%  269M 3s
#  20000K .......... .......... .......... .......... .......... 29%  281M 3s
#  20050K .......... .......... .......... .......... .......... 29% 13.9M 3s
#  20100K .......... .......... .......... .......... .......... 29%  266M 3s
#  20150K .......... .......... .......... .......... .......... 29% 1.21M 3s
#  20200K .......... .......... .......... .......... .......... 29%  109M 3s
#  20250K .......... .......... .......... .......... .......... 30% 71.4M 3s
#  20300K .......... .......... .......... .......... .......... 30%  127M 3s
#  20350K .......... .......... .......... .......... .......... 30%  266M 3s
#  20400K .......... .......... .......... .......... .......... 30%  268M 3s
#  20450K .......... .......... .......... .......... .......... 30%  226M 3s
#  20500K .......... .......... .......... .......... .......... 30%  274M 3s
#  20550K .......... .......... .......... .......... .......... 30%  278M 3s
#  20600K .......... .......... .......... .......... .......... 30% 57.4M 3s
#  20650K .......... .......... .......... .......... .......... 30%  110M 3s
#  20700K .......... .......... .......... .......... .......... 30%  115M 3s
#  20750K .......... .......... .......... .......... .......... 30% 86.4M 3s
#  20800K .......... .......... .......... .......... .......... 30%  267M 3s
#  20850K .......... .......... .......... .......... .......... 30%  231M 3s
#  20900K .......... .......... .......... .......... .......... 31%  268M 2s
#  20950K .......... .......... .......... .......... .......... 31%  272M 2s
#  21000K .......... .......... .......... .......... .......... 31% 8.96M 2s
#  21050K .......... .......... .......... .......... .......... 31% 44.0M 2s
#  21100K .......... .......... .......... .......... .......... 31%  136M 2s
#  21150K .......... .......... .......... .......... .......... 31%  128M 2s
#  21200K .......... .......... .......... .......... .......... 31%  101M 2s
#  21250K .......... .......... .......... .......... .......... 31%  164M 2s
#  21300K .......... .......... .......... .......... .......... 31%  246M 2s
#  21350K .......... .......... .......... .......... .......... 31%  285M 2s
#  21400K .......... .......... .......... .......... .......... 31%  223M 2s
#  21450K .......... .......... .......... .......... .......... 31%  160M 2s
#  21500K .......... .......... .......... .......... .......... 31%  239M 2s
#  21550K .......... .......... .......... .......... .......... 31% 15.0M 2s
#  21600K .......... .......... .......... .......... .......... 32% 95.5M 2s
#  21650K .......... .......... .......... .......... .......... 32% 1.23M 2s
#  21700K .......... .......... .......... .......... .......... 32% 91.5M 2s
#  21750K .......... .......... .......... .......... .......... 32%  194M 2s
#  21800K .......... .......... .......... .......... .......... 32%  161M 2s
#  21850K .......... .......... .......... .......... .......... 32%  204M 2s
#  21900K .......... .......... .......... .......... .......... 32%  235M 2s
#  21950K .......... .......... .......... .......... .......... 32%  135M 2s
#  22000K .......... .......... .......... .......... .......... 32%  109M 2s
#  22050K .......... .......... .......... .......... .......... 32%  200M 2s
#  22100K .......... .......... .......... .......... .......... 32% 52.5M 2s
#  22150K .......... .......... .......... .......... .......... 32%  154M 2s
#  22200K .......... .......... .......... .......... .......... 32% 54.8M 2s
#  22250K .......... .......... .......... .......... .......... 33% 69.5M 2s
#  22300K .......... .......... .......... .......... .......... 33%  267M 2s
#  22350K .......... .......... .......... .......... .......... 33%  272M 2s
#  22400K .......... .......... .......... .......... .......... 33%  279M 2s
#  22450K .......... .......... .......... .......... .......... 33%  224M 2s
#  22500K .......... .......... .......... .......... .......... 33% 9.49M 2s
#  22550K .......... .......... .......... .......... .......... 33% 43.1M 2s
#  22600K .......... .......... .......... .......... .......... 33%  142M 2s
#  22650K .......... .......... .......... .......... .......... 33%  109M 2s
#  22700K .......... .......... .......... .......... .......... 33%  107M 2s
#  22750K .......... .......... .......... .......... .......... 33%  161M 2s
#  22800K .......... .......... .......... .......... .......... 33%  169M 2s
#  22850K .......... .......... .......... .......... .......... 33%  205M 2s
#  22900K .......... .......... .......... .......... .......... 33%  188M 2s
#  22950K .......... .......... .......... .......... .......... 34%  180M 2s
#  23000K .......... .......... .......... .......... .......... 34%  266M 2s
#  23050K .......... .......... .......... .......... .......... 34% 16.8M 2s
#  23100K .......... .......... .......... .......... .......... 34% 74.1M 2s
#  23150K .......... .......... .......... .......... .......... 34%  133M 2s
#  23200K .......... .......... .......... .......... .......... 34% 1.31M 2s
#  23250K .......... .......... .......... .......... .......... 34% 18.0M 2s
#  23300K .......... .......... .......... .......... .......... 34%  148M 2s
#  23350K .......... .......... .......... .......... .......... 34%  148M 2s
#  23400K .......... .......... .......... .......... .......... 34%  261M 2s
#  23450K .......... .......... .......... .......... .......... 34% 75.4M 2s
#  23500K .......... .......... .......... .......... .......... 34%  145M 2s
#  23550K .......... .......... .......... .......... .......... 34%  257M 2s
#  23600K .......... .......... .......... .......... .......... 35%  285M 2s
#  23650K .......... .......... .......... .......... .......... 35% 49.6M 2s
#  23700K .......... .......... .......... .......... .......... 35% 50.5M 2s
#  23750K .......... .......... .......... .......... .......... 35%  186M 2s
#  23800K .......... .......... .......... .......... .......... 35%  115M 2s
#  23850K .......... .......... .......... .......... .......... 35%  163M 2s
#  23900K .......... .......... .......... .......... .......... 35% 98.9M 2s
#  23950K .......... .......... .......... .......... .......... 35%  191M 2s
#  24000K .......... .......... .......... .......... .......... 35% 11.1M 2s
#  24050K .......... .......... .......... .......... .......... 35% 35.5M 2s
#  24100K .......... .......... .......... .......... .......... 35% 83.3M 2s
#  24150K .......... .......... .......... .......... .......... 35% 76.1M 2s
#  24200K .......... .......... .......... .......... .......... 35% 96.8M 2s
#  24250K .......... .......... .......... .......... .......... 35%  152M 2s
#  24300K .......... .......... .......... .......... .......... 36%  259M 2s
#  24350K .......... .......... .......... .......... .......... 36%  219M 2s
#  24400K .......... .......... .......... .......... .......... 36%  163M 2s
#  24450K .......... .......... .......... .......... .......... 36%  231M 2s
#  24500K .......... .......... .......... .......... .......... 36%  264M 2s
#  24550K .......... .......... .......... .......... .......... 36% 18.4M 2s
#  24600K .......... .......... .......... .......... .......... 36%  248M 2s
#  24650K .......... .......... .......... .......... .......... 36% 49.1M 2s
#  24700K .......... .......... .......... .......... .......... 36%  264M 2s
#  24750K .......... .......... .......... .......... .......... 36% 1.23M 2s
#  24800K .......... .......... .......... .......... .......... 36%  168M 2s
#  24850K .......... .......... .......... .......... .......... 36% 63.4M 2s
#  24900K .......... .......... .......... .......... .......... 36%  100M 2s
#  24950K .......... .......... .......... .......... .......... 37%  150M 2s
#  25000K .......... .......... .......... .......... .......... 37%  163M 2s
#  25050K .......... .......... .......... .......... .......... 37%  235M 2s
#  25100K .......... .......... .......... .......... .......... 37%  281M 2s
#  25150K .......... .......... .......... .......... .......... 37%  113M 2s
#  25200K .......... .......... .......... .......... .......... 37% 49.5M 2s
#  25250K .......... .......... .......... .......... .......... 37% 98.3M 2s
#  25300K .......... .......... .......... .......... .......... 37%  220M 2s
#  25350K .......... .......... .......... .......... .......... 37%  247M 2s
#  25400K .......... .......... .......... .......... .......... 37%  222M 2s
#  25450K .......... .......... .......... .......... .......... 37%  228M 2s
#  25500K .......... .......... .......... .......... .......... 37% 68.9M 2s
#  25550K .......... .......... .......... .......... .......... 37% 11.4M 2s
#  25600K .......... .......... .......... .......... .......... 37% 33.3M 2s
#  25650K .......... .......... .......... .......... .......... 38% 38.0M 2s
#  25700K .......... .......... .......... .......... .......... 38%  231M 2s
#  25750K .......... .......... .......... .......... .......... 38%  215M 2s
#  25800K .......... .......... .......... .......... .......... 38%  241M 2s
#  25850K .......... .......... .......... .......... .......... 38%  219M 2s
#  25900K .......... .......... .......... .......... .......... 38%  252M 2s
#  25950K .......... .......... .......... .......... .......... 38%  247M 2s
#  26000K .......... .......... .......... .......... .......... 38%  257M 2s
#  26050K .......... .......... .......... .......... .......... 38% 17.0M 2s
#  26100K .......... .......... .......... .......... .......... 38%  212M 2s
#  26150K .......... .......... .......... .......... .......... 38% 50.7M 2s
#  26200K .......... .......... .......... .......... .......... 38%  251M 2s
#  26250K .......... .......... .......... .......... .......... 38%  197M 2s
#  26300K .......... .......... .......... .......... .......... 39% 1.24M 2s
#  26350K .......... .......... .......... .......... .......... 39% 48.3M 2s
#  26400K .......... .......... .......... .......... .......... 39%  207M 2s
#  26450K .......... .......... .......... .......... .......... 39% 95.9M 2s
#  26500K .......... .......... .......... .......... .......... 39%  192M 2s
#  26550K .......... .......... .......... .......... .......... 39%  186M 2s
#  26600K .......... .......... .......... .......... .......... 39%  236M 2s
#  26650K .......... .......... .......... .......... .......... 39% 64.1M 2s
#  26700K .......... .......... .......... .......... .......... 39% 59.5M 2s
#  26750K .......... .......... .......... .......... .......... 39%  117M 2s
#  26800K .......... .......... .......... .......... .......... 39%  134M 2s
#  26850K .......... .......... .......... .......... .......... 39%  206M 2s
#  26900K .......... .......... .......... .......... .......... 39% 85.7M 2s
#  26950K .......... .......... .......... .......... .......... 39%  245M 2s
#  27000K .......... .......... .......... .......... .......... 40% 83.9M 2s
#  27050K .......... .......... .......... .......... .......... 40%  226M 2s
#  27100K .......... .......... .......... .......... .......... 40% 9.50M 2s
#  27150K .......... .......... .......... .......... .......... 40% 38.5M 2s
#  27200K .......... .......... .......... .......... .......... 40%  166M 2s
#  27250K .......... .......... .......... .......... .......... 40%  123M 2s
#  27300K .......... .......... .......... .......... .......... 40% 77.2M 2s
#  27350K .......... .......... .......... .......... .......... 40%  138M 2s
#  27400K .......... .......... .......... .......... .......... 40%  260M 2s
#  27450K .......... .......... .......... .......... .......... 40%  198M 2s
#  27500K .......... .......... .......... .......... .......... 40%  251M 2s
#  27550K .......... .......... .......... .......... .......... 40%  284M 2s
#  27600K .......... .......... .......... .......... .......... 40% 22.0M 2s
#  27650K .......... .......... .......... .......... .......... 41% 47.0M 2s
#  27700K .......... .......... .......... .......... .......... 41%  151M 2s
#  27750K .......... .......... .......... .......... .......... 41%  157M 2s
#  27800K .......... .......... .......... .......... .......... 41%  237M 2s
#  27850K .......... .......... .......... .......... .......... 41% 1.23M 2s
#  27900K .......... .......... .......... .......... .......... 41% 82.0M 2s
#  27950K .......... .......... .......... .......... .......... 41%  171M 2s
#  28000K .......... .......... .......... .......... .......... 41%  156M 2s
#  28050K .......... .......... .......... .......... .......... 41%  135M 2s
#  28100K .......... .......... .......... .......... .......... 41%  207M 2s
#  28150K .......... .......... .......... .......... .......... 41% 64.9M 2s
#  28200K .......... .......... .......... .......... .......... 41% 63.7M 2s
#  28250K .......... .......... .......... .......... .......... 41%  161M 2s
#  28300K .......... .......... .......... .......... .......... 41%  108M 2s
#  28350K .......... .......... .......... .......... .......... 42%  259M 2s
#  28400K .......... .......... .......... .......... .......... 42%  133M 2s
#  28450K .......... .......... .......... .......... .......... 42%  140M 2s
#  28500K .......... .......... .......... .......... .......... 42% 26.0M 2s
#  28550K .......... .......... .......... .......... .......... 42%  149M 2s
#  28600K .......... .......... .......... .......... .......... 42% 22.1M 2s
#  28650K .......... .......... .......... .......... .......... 42% 18.6M 2s
#  28700K .......... .......... .......... .......... .......... 42%  130M 2s
#  28750K .......... .......... .......... .......... .......... 42%  150M 2s
#  28800K .......... .......... .......... .......... .......... 42%  124M 2s
#  28850K .......... .......... .......... .......... .......... 42%  140M 2s
#  28900K .......... .......... .......... .......... .......... 42%  230M 2s
#  28950K .......... .......... .......... .......... .......... 42%  251M 2s
#  29000K .......... .......... .......... .......... .......... 43%  258M 2s
#  29050K .......... .......... .......... .......... .......... 43%  216M 2s
#  29100K .......... .......... .......... .......... .......... 43% 18.5M 2s
#  29150K .......... .......... .......... .......... .......... 43% 42.3M 2s
#  29200K .......... .......... .......... .......... .......... 43%  189M 2s
#  29250K .......... .......... .......... .......... .......... 43%  196M 2s
#  29300K .......... .......... .......... .......... .......... 43%  205M 2s
#  29350K .......... .......... .......... .......... .......... 43%  150M 2s
#  29400K .......... .......... .......... .......... .......... 43% 1.22M 2s
#  29450K .......... .......... .......... .......... .......... 43%  122M 2s
#  29500K .......... .......... .......... .......... .......... 43%  110M 2s
#  29550K .......... .......... .......... .......... .......... 43% 80.2M 2s
#  29600K .......... .......... .......... .......... .......... 43%  228M 2s
#  29650K .......... .......... .......... .......... .......... 43%  119M 2s
#  29700K .......... .......... .......... .......... .......... 44% 62.5M 2s
#  29750K .......... .......... .......... .......... .......... 44%  181M 2s
#  29800K .......... .......... .......... .......... .......... 44%  104M 2s
#  29850K .......... .......... .......... .......... .......... 44%  172M 2s
#  29900K .......... .......... .......... .......... .......... 44%  156M 2s
#  29950K .......... .......... .......... .......... .......... 44%  206M 2s
#  30000K .......... .......... .......... .......... .......... 44%  215M 2s
#  30050K .......... .......... .......... .......... .......... 44% 31.6M 2s
#  30100K .......... .......... .......... .......... .......... 44% 21.0M 2s
#  30150K .......... .......... .......... .......... .......... 44% 15.6M 2s
#  30200K .......... .......... .......... .......... .......... 44%  180M 2s
#  30250K .......... .......... .......... .......... .......... 44%  128M 2s
#  30300K .......... .......... .......... .......... .......... 44%  160M 2s
#  30350K .......... .......... .......... .......... .......... 45%  101M 2s
#  30400K .......... .......... .......... .......... .......... 45%  143M 2s
#  30450K .......... .......... .......... .......... .......... 45%  156M 2s
#  30500K .......... .......... .......... .......... .......... 45%  275M 2s
#  30550K .......... .......... .......... .......... .......... 45%  262M 2s
#  30600K .......... .......... .......... .......... .......... 45% 5.18M 2s
#  30650K .......... .......... .......... .......... .......... 45%  221M 2s
#  30700K .......... .......... .......... .......... .......... 45%  254M 2s
#  30750K .......... .......... .......... .......... .......... 45%  262M 2s
#  30800K .......... .......... .......... .......... .......... 45%  256M 2s
#  30850K .......... .......... .......... .......... .......... 45%  215M 2s
#  30900K .......... .......... .......... .......... .......... 45% 1.57M 2s
#  30950K .......... .......... .......... .......... .......... 45% 13.8M 2s
#  31000K .......... .......... .......... .......... .......... 45%  123M 2s
#  31050K .......... .......... .......... .......... .......... 46% 92.5M 2s
#  31100K .......... .......... .......... .......... .......... 46%  147M 2s
#  31150K .......... .......... .......... .......... .......... 46% 95.6M 2s
# ...
#  57150K .......... .......... .......... .......... .......... 84% 3.67M 0s
#  57200K .......... .......... .......... .......... .......... 84% 12.9M 0s
#  57250K .......... .......... .......... .......... .......... 84% 58.1M 0s
#  57300K .......... .......... .......... .......... .......... 84% 71.3M 0s
#  57350K .......... .......... .......... .......... .......... 84%  209M 0s
#  57400K .......... .......... .......... .......... .......... 85% 97.0M 0s
#  57450K .......... .......... .......... .......... .......... 85%  154M 0s
#  57500K .......... .......... .......... .......... .......... 85%  206M 0s
#  57550K .......... .......... .......... .......... .......... 85%  261M 0s
#  57600K .......... .......... .......... .......... .......... 85%  111M 0s
#  57650K .......... .......... .......... .......... .......... 85%  114M 0s
#  57700K .......... .......... .......... .......... .......... 85%  120M 0s
#  57750K .......... .......... .......... .......... .......... 85%  109M 0s
#  57800K .......... .......... .......... .......... .......... 85%  256M 0s
#  57850K .......... .......... .......... .......... .......... 85%  194M 0s
#  57900K .......... .......... .......... .......... .......... 85%  263M 0s
#  57950K .......... .......... .......... .......... .......... 85%  209M 0s
#  58000K .......... .......... .......... .......... .......... 85%  267M 0s
#  58050K .......... .......... .......... .......... .......... 86% 18.7M 0s
#  58100K .......... .......... .......... .......... .......... 86% 35.6M 0s
#  58150K .......... .......... .......... .......... .......... 86% 64.8M 0s
#  58200K .......... .......... .......... .......... .......... 86%  114M 0s
#  58250K .......... .......... .......... .......... .......... 86% 71.4M 0s
#  58300K .......... .......... .......... .......... .......... 86% 94.1M 0s
#  58350K .......... .......... .......... .......... .......... 86%  129M 0s
#  58400K .......... .......... .......... .......... .......... 86%  266M 0s
#  58450K .......... .......... .......... .......... .......... 86%  105M 0s
#  58500K .......... .......... .......... .......... .......... 86%  263M 0s
#  58550K .......... .......... .......... .......... .......... 86%  213M 0s
#  58600K .......... .......... .......... .......... .......... 86% 2.03M 0s
#  58650K .......... .......... .......... .......... .......... 86% 4.20M 0s
#  58700K .......... .......... .......... .......... .......... 86% 5.40M 0s
#  58750K .......... .......... .......... .......... .......... 87% 59.3M 0s
#  58800K .......... .......... .......... .......... .......... 87% 49.4M 0s
#  58850K .......... .......... .......... .......... .......... 87%  142M 0s
#  58900K .......... .......... .......... .......... .......... 87%  124M 0s
#  58950K .......... .......... .......... .......... .......... 87%  151M 0s
#  59000K .......... .......... .......... .......... .......... 87%  245M 0s
#  59050K .......... .......... .......... .......... .......... 87%  198M 0s
#  59100K .......... .......... .......... .......... .......... 87%  209M 0s
#  59150K .......... .......... .......... .......... .......... 87%  140M 0s
#  59200K .......... .......... .......... .......... .......... 87%  224M 0s
#  59250K .......... .......... .......... .......... .......... 87% 79.6M 0s
#  59300K .......... .......... .......... .......... .......... 87%  202M 0s
#  59350K .......... .......... .......... .......... .......... 87%  172M 0s
#  59400K .......... .......... .......... .......... .......... 88%  276M 0s
#  59450K .......... .......... .......... .......... .......... 88%  240M 0s
#  59500K .......... .......... .......... .......... .......... 88%  254M 0s
#  59550K .......... .......... .......... .......... .......... 88% 19.3M 0s
#  59600K .......... .......... .......... .......... .......... 88%  254M 0s
#  59650K .......... .......... .......... .......... .......... 88% 27.6M 0s
#  59700K .......... .......... .......... .......... .......... 88% 44.9M 0s
#  59750K .......... .......... .......... .......... .......... 88%  110M 0s
#  59800K .......... .......... .......... .......... .......... 88%  161M 0s
#  59850K .......... .......... .......... .......... .......... 88% 75.5M 0s
#  59900K .......... .......... .......... .......... .......... 88%  270M 0s
#  59950K .......... .......... .......... .......... .......... 88%  267M 0s
#  60000K .......... .......... .......... .......... .......... 88%  152M 0s
#  60050K .......... .......... .......... .......... .......... 88%  170M 0s
#  60100K .......... .......... .......... .......... .......... 89% 2.02M 0s
#  60150K .......... .......... .......... .......... .......... 89% 8.16M 0s
#  60200K .......... .......... .......... .......... .......... 89% 4.17M 0s
#  60250K .......... .......... .......... .......... .......... 89% 13.4M 0s
#  60300K .......... .......... .......... .......... .......... 89%  198M 0s
#  60350K .......... .......... .......... .......... .......... 89%  147M 0s
#  60400K .......... .......... .......... .......... .......... 89%  246M 0s
#  60450K .......... .......... .......... .......... .......... 89%  202M 0s
#  60500K .......... .......... .......... .......... .......... 89%  259M 0s
#  60550K .......... .......... .......... .......... .......... 89%  233M 0s
#  60600K .......... .......... .......... .......... .......... 89%  225M 0s
#  60650K .......... .......... .......... .......... .......... 89%  230M 0s
#  60700K .......... .......... .......... .......... .......... 89%  249M 0s
#  60750K .......... .......... .......... .......... .......... 90%  157M 0s
#  60800K .......... .......... .......... .......... .......... 90% 65.0M 0s
#  60850K .......... .......... .......... .......... .......... 90% 52.1M 0s
#  60900K .......... .......... .......... .......... .......... 90%  214M 0s
#  60950K .......... .......... .......... .......... .......... 90%  255M 0s
#  61000K .......... .......... .......... .......... .......... 90%  197M 0s
#  61050K .......... .......... .......... .......... .......... 90% 17.2M 0s
#  61100K .......... .......... .......... .......... .......... 90%  247M 0s
#  61150K .......... .......... .......... .......... .......... 90% 30.5M 0s
#  61200K .......... .......... .......... .......... .......... 90% 40.3M 0s
#  61250K .......... .......... .......... .......... .......... 90%  106M 0s
#  61300K .......... .......... .......... .......... .......... 90%  123M 0s
#  61350K .......... .......... .......... .......... .......... 90%  264M 0s
#  61400K .......... .......... .......... .......... .......... 90%  233M 0s
#  61450K .......... .......... .......... .......... .......... 91%  180M 0s
#  61500K .......... .......... .......... .......... .......... 91%  183M 0s
#  61550K .......... .......... .......... .......... .......... 91% 95.1M 0s
#  61600K .......... .......... .......... .......... .......... 91%  158M 0s
#  61650K .......... .......... .......... .......... .......... 91% 1.88M 0s
#  61700K .......... .......... .......... .......... .......... 91% 5.08M 0s
#  61750K .......... .......... .......... .......... .......... 91% 5.10M 0s
#  61800K .......... .......... .......... .......... .......... 91%  116M 0s
#  61850K .......... .......... .......... .......... .......... 91%  194M 0s
#  61900K .......... .......... .......... .......... .......... 91% 89.1M 0s
#  61950K .......... .......... .......... .......... .......... 91% 99.4M 0s
#  62000K .......... .......... .......... .......... .......... 91%  111M 0s
#  62050K .......... .......... .......... .......... .......... 91% 86.0M 0s
#  62100K .......... .......... .......... .......... .......... 92%  274M 0s
#  62150K .......... .......... .......... .......... .......... 92%  255M 0s
#  62200K .......... .......... .......... .......... .......... 92%  285M 0s
#  62250K .......... .......... .......... .......... .......... 92%  244M 0s
#  62300K .......... .......... .......... .......... .......... 92%  146M 0s
#  62350K .......... .......... .......... .......... .......... 92%  284M 0s
#  62400K .......... .......... .......... .......... .......... 92% 80.0M 0s
#  62450K .......... .......... .......... .......... .......... 92%  139M 0s
#  62500K .......... .......... .......... .......... .......... 92%  197M 0s
#  62550K .......... .......... .......... .......... .......... 92% 21.4M 0s
#  62600K .......... .......... .......... .......... .......... 92%  131M 0s
#  62650K .......... .......... .......... .......... .......... 92% 30.1M 0s
#  62700K .......... .......... .......... .......... .......... 92% 32.8M 0s
#  62750K .......... .......... .......... .......... .......... 92%  139M 0s
#  62800K .......... .......... .......... .......... .......... 93%  122M 0s
#  62850K .......... .......... .......... .......... .......... 93% 99.3M 0s
#  62900K .......... .......... .......... .......... .......... 93%  142M 0s
#  62950K .......... .......... .......... .......... .......... 93%  164M 0s
#  63000K .......... .......... .......... .......... .......... 93%  272M 0s
#  63050K .......... .......... .......... .......... .......... 93%  205M 0s
#  63100K .......... .......... .......... .......... .......... 93%  112M 0s
#  63150K .......... .......... .......... .......... .......... 93% 77.1M 0s
#  63200K .......... .......... .......... .......... .......... 93% 1.95M 0s
#  63250K .......... .......... .......... .......... .......... 93% 3.09M 0s
#  63300K .......... .......... .......... .......... .......... 93% 12.9M 0s
#  63350K .......... .......... .......... .......... .......... 93%  121M 0s
#  63400K .......... .......... .......... .......... .......... 93% 87.2M 0s
#  63450K .......... .......... .......... .......... .......... 94% 64.4M 0s
#  63500K .......... .......... .......... .......... .......... 94% 77.3M 0s
#  63550K .......... .......... .......... .......... .......... 94%  256M 0s
#  63600K .......... .......... .......... .......... .......... 94%  262M 0s
#  63650K .......... .......... .......... .......... .......... 94%  228M 0s
#  63700K .......... .......... .......... .......... .......... 94%  266M 0s
#  63750K .......... .......... .......... .......... .......... 94%  127M 0s
#  63800K .......... .......... .......... .......... .......... 94%  259M 0s
#  63850K .......... .......... .......... .......... .......... 94%  200M 0s
#  63900K .......... .......... .......... .......... .......... 94%  162M 0s
#  63950K .......... .......... .......... .......... .......... 94%  140M 0s
#  64000K .......... .......... .......... .......... .......... 94%  146M 0s
#  64050K .......... .......... .......... .......... .......... 94% 24.7M 0s
#  64100K .......... .......... .......... .......... .......... 94% 93.5M 0s
#  64150K .......... .......... .......... .......... .......... 95% 29.4M 0s
#  64200K .......... .......... .......... .......... .......... 95% 39.5M 0s
#  64250K .......... .......... .......... .......... .......... 95% 54.5M 0s
#  64300K .......... .......... .......... .......... .......... 95%  120M 0s
#  64350K .......... .......... .......... .......... .......... 95%  165M 0s
#  64400K .......... .......... .......... .......... .......... 95% 88.9M 0s
#  64450K .......... .......... .......... .......... .......... 95%  127M 0s
#  64500K .......... .......... .......... .......... .......... 95%  210M 0s
#  64550K .......... .......... .......... .......... .......... 95%  123M 0s
#  64600K .......... .......... .......... .......... .......... 95%  196M 0s
#  64650K .......... .......... .......... .......... .......... 95% 90.9M 0s
#  64700K .......... .......... .......... .......... .......... 95% 1.97M 0s
#  64750K .......... .......... .......... .......... .......... 95% 9.45M 0s
#  64800K .......... .......... .......... .......... .......... 96% 4.70M 0s
#  64850K .......... .......... .......... .......... .......... 96% 11.5M 0s
#  64900K .......... .......... .......... .......... .......... 96% 35.5M 0s
#  64950K .......... .......... .......... .......... .......... 96%  107M 0s
#  65000K .......... .......... .......... .......... .......... 96% 86.5M 0s
#  65050K .......... .......... .......... .......... .......... 96%  238M 0s
#  65100K .......... .......... .......... .......... .......... 96%  163M 0s
#  65150K .......... .......... .......... .......... .......... 96%  132M 0s
#  65200K .......... .......... .......... .......... .......... 96%  261M 0s
#  65250K .......... .......... .......... .......... .......... 96%  174M 0s
#  65300K .......... .......... .......... .......... .......... 96%  204M 0s
#  65350K .......... .......... .......... .......... .......... 96%  150M 0s
#  65400K .......... .......... .......... .......... .......... 96%  115M 0s
#  65450K .......... .......... .......... .......... .......... 96%  128M 0s
#  65500K .......... .......... .......... .......... .......... 97%  273M 0s
#  65550K .......... .......... .......... .......... .......... 97%  203M 0s
#  65600K .......... .......... .......... .......... .......... 97% 37.4M 0s
#  65650K .......... .......... .......... .......... .......... 97% 19.3M 0s
#  65700K .......... .......... .......... .......... .......... 97% 57.4M 0s
#  65750K .......... .......... .......... .......... .......... 97% 55.0M 0s
#  65800K .......... .......... .......... .......... .......... 97%  105M 0s
#  65850K .......... .......... .......... .......... .......... 97%  144M 0s
#  65900K .......... .......... .......... .......... .......... 97% 85.0M 0s
#  65950K .......... .......... .......... .......... .......... 97% 89.9M 0s
#  66000K .......... .......... .......... .......... .......... 97%  118M 0s
#  66050K .......... .......... .......... .......... .......... 97%  229M 0s
#  66100K .......... .......... .......... .......... .......... 97%  136M 0s
#  66150K .......... .......... .......... .......... .......... 98%  166M 0s
#  66200K .......... .......... .......... .......... .......... 98% 2.00M 0s
#  66250K .......... .......... .......... .......... .......... 98% 87.4M 0s
#  66300K .......... .......... .......... .......... .......... 98% 5.18M 0s
#  66350K .......... .......... .......... .......... .......... 98% 6.21M 0s
#  66400K .......... .......... .......... .......... .......... 98% 18.3M 0s
#  66450K .......... .......... .......... .......... .......... 98%  124M 0s
#  66500K .......... .......... .......... .......... .......... 98%  122M 0s
#  66550K .......... .......... .......... .......... .......... 98%  216M 0s
#  66600K .......... .......... .......... .......... .......... 98%  220M 0s
#  66650K .......... .......... .......... .......... .......... 98%  215M 0s
#  66700K .......... .......... .......... .......... .......... 98%  244M 0s
#  66750K .......... .......... .......... .......... .......... 98%  270M 0s
#  66800K .......... .......... .......... .......... .......... 98%  255M 0s
#  66850K .......... .......... .......... .......... .......... 99% 66.2M 0s
#  66900K .......... .......... .......... .......... .......... 99% 44.9M 0s
#  66950K .......... .......... .......... .......... .......... 99%  207M 0s
#  67000K .......... .......... .......... .......... .......... 99%  129M 0s
#  67050K .......... .......... .......... .......... .......... 99%  237M 0s
#  67100K .......... .......... .......... .......... .......... 99% 12.0M 0s
#  67150K .......... .......... .......... .......... .......... 99%  197M 0s
#  67200K .......... .......... .......... .......... .......... 99%  267M 0s
#  67250K .......... .......... .......... .......... .......... 99% 68.5M 0s
#  67300K .......... .......... .......... .......... .......... 99% 63.7M 0s
#  67350K .......... .......... .......... .......... .......... 99% 95.5M 0s
#  67400K .......... .......... .......... .......... .......... 99% 59.6M 0s
#  67450K .......... .......... .......... .......... .......... 99%  213M 0s
#  67500K .......... .......... .......... ....                 100%  263M=2.9s
#
# 2023-12-06 14:25:23 (22.7 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('creditcard.csv', delimiter=',')

# %% [markdown]
# Let's take a peek at our data (we only show a subset of the columns in the table):

# %%
print(data.columns)
data[['Time', 'V1', 'V2', 'V27', 'V28', 'Amount', 'Class']].describe()
data.head(10)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %% [markdown]
# The class column corresponds to whether or not a transaction is fradulent. We see that the majority of data is non-fraudulant with only $492$ ($.173\%$) of the data corresponding to fraudulant examples.

# %%
nonfrauds, frauds = data.groupby('Class').size()
print('Number of frauds: ', frauds)
print('Number of non-frauds: ', nonfrauds)
print('Percentage of fradulent data:', 100.*frauds/(frauds + nonfrauds))
# Out:
# Number of frauds:  492
# Number of non-frauds:  284315
# Percentage of fradulent data: 0.1727485630620034

# %% [markdown]
# This dataset has 28 columns, $V_i$ for $i=1..28$ of anonymized features along with columns for time, amount, and class. We already know that the columns $V_i$ have been normalized to have $0$ mean and unit standard deviation as the result of a PCA. You can read more about PCA here:.
#
# Tip: For our dataset this amount of preprocessing will give us reasonable accuracy, but it's important to note that there are more preprocessing steps one can use to improve accuracy . For unbalanced data sets like ours where the positive (fraudulent) examples occur much less frequently than the negative (legitimate) examples, we may try “over-sampling” the minority dataset by generating synthetic data (read about SMOTE in Data Mining for Imbalanced Datasets: An Overview (https://link.springer.com/chapter/10.1007%2F0-387-25465-X_40) or undersampling the majority class by using ensemble methods (see http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.68.6858&rep=rep1&type=pdfor).

# %%
feature_columns = data.columns[:-1]
label_column = data.columns[-1]

features = data[feature_columns].values.astype('float32')
labels = (data[label_column].values).astype('float32')

# %% [markdown]
# Let's do some analysis and discuss different ways we can preprocess our data. Let's discuss the way in which this data was preprocessed.

# %% [markdown]
# ## SageMaker XGB

# %% [markdown]
# ### Prepare Data and Upload to S3

# %% [markdown]
# The Amazon common libraries provide utilities to convert NumPy n-dimensional arrays into a the Record-IO format which SageMaker uses for a concise representation of features and labels. The Record-IO format is implemented via protocol buffer so the serialization is very efficient.

# %%
model_data = data
model_data.head()
model_data = pd.concat([model_data['Class'], model_data.drop(['Class'], axis=1)], axis=1)
model_data.head()
# Out:
#    Class  Time        V1        V2        V3        V4        V5        V6  \
# 0      0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1      0   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2      0   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3      0   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4      0   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8  ...       V20       V21       V22       V23       V24  \
# 0  0.239599  0.098698  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1  0.167170  0.125895 -0.008983  0.014724    2.69
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3  0.647376 -0.221929  0.062723  0.061458  123.50
# 4 -0.206010  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Now we upload the data to S3 using boto3.

# %%
import boto3
import os
import sagemaker

session = sagemaker.Session()

bucket = session.default_bucket()
sagemaker_iam_role = sagemaker.get_execution_role()

prefix = 'sagemaker/DEMO-xgboost-fraud'

train_data, validation_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), 
                                                  [int(0.7 * len(model_data)), int(0.9 * len(model_data))])
train_data.to_csv('train.csv', header=False, index=False)
validation_data.to_csv('validation.csv', header=False, index=False)


boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')) \
                                .upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')) \
                                .upload_file('validation.csv')
s3_train_data = 's3://{}/{}/train/train.csv'.format(bucket, prefix)
s3_validation_data = 's3://{}/{}/validation/validation.csv'.format(bucket, prefix)
print('Uploaded training data location: {}'.format(s3_train_data))
print('Uploaded training data location: {}'.format(s3_validation_data))

output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('Training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Uploaded training data location: s3://sagemaker-us-east-1-105755463314/sagemaker/DEMO-xgboost-fraud/train/train.csv
# Uploaded training data location: s3://sagemaker-us-east-1-105755463314/sagemaker/DEMO-xgboost-fraud/validation/validation.csv
# Training artifacts will be uploaded to: s3://sagemaker-us-east-1-105755463314/sagemaker/DEMO-xgboost-fraud/output

# %% [markdown]
# ---
# ## Train
#
# Moving onto training, first we'll need to specify the locations of the XGBoost algorithm containers.
# To specify the Linear Learner algorithm, we use a utility function to obtain it's URI. A complete list of build-in algorithms is found here: https://docs.aws.amazon.com/sagemaker/latest/dg/algos.html

# %%
from sagemaker.amazon.amazon_estimator import image_uris
container = image_uris.retrieve("xgboost", boto3.Session().region_name, version="latest")

# %% [markdown]
# Then, because we're training with the CSV file format, we'll create s3_inputs that our training function can use as a pointer to the files in S3.

# %%
from sagemaker.inputs import TrainingInput

# Assuming you are using TrainingInput for training data
s3_input_train = TrainingInput(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')

# Assuming you are using TrainingInput for validation data
s3_input_validation = TrainingInput(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')

# %% [markdown]
# Now, we can specify a few parameters like what type of training instances we'd like to use and how many, as well as our XGBoost hyperparameters.  A few key hyperparameters are:
# - `max_depth` controls how deep each tree within the algorithm can be built.  Deeper trees can lead to better fit, but are more computationally expensive and can lead to overfitting.  There is typically some trade-off in model performance that needs to be explored between a large number of shallow trees and a smaller number of deeper trees.
# - `subsample` controls sampling of the training data.  This technique can help reduce overfitting, but setting it too low can also starve the model of data.
# - `num_round` controls the number of boosting rounds.  This is essentially the subsequent models that are trained using the residuals of previous iterations.  Again, more rounds should produce a better fit on the training data, but can be computationally expensive or lead to overfitting.
# - `eta` controls how aggressive each round of boosting is.  Larger values lead to more conservative boosting.
# - `gamma` controls how aggressively trees are grown.  Larger values lead to more conservative models.
#
# More detail on XGBoost's hyperparmeters can be found on their GitHub [page](https://github.com/dmlc/xgboost/blob/master/doc/parameter.md).

# %% [markdown]
# SageMaker abstracts training with Estimators. We can pass container, and all parameters to the estimator, as well as the hyperparameters for the linear learner and fit the estimator to the data in S3.
# Note: For IP protection reasons, SageMaker built-in algorithms, such as XGBoost, can't be run locally, i.e. on the same instance where this Jupyter Notebook code is running.

# %%
xgb = sagemaker.estimator.Estimator(container,
                                    role=sagemaker_iam_role, 
                                    instance_count=1,  # Updated parameter name
                                    instance_type='ml.m4.xlarge',  # Updated parameter name
                                    output_path=output_location,
                                    sagemaker_session=session)
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        num_round=100)  # Ensure that num_round is set to an appropriate value

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# INFO:sagemaker:Creating training-job with name: xgboost-2023-12-06-14-51-51-296
# 2023-12-06 14:51:51 Starting - Starting the training job...
# 2023-12-06 14:52:16 Starting - Preparing the instances for training............
# 2023-12-06 14:53:54 Downloading - Downloading input data...
# 2023-12-06 14:54:34 Training - Downloading the training image...
# 2023-12-06 14:55:04 Training - Training image download completed. Training in progress..Arguments: train
# [2023-12-06:14:55:18:INFO] Running standalone xgboost training.
# [2023-12-06:14:55:18:INFO] File size need to be processed in the node: 129.45mb. Available memory size in the node: 8545.95mb
# [2023-12-06:14:55:18:INFO] Determined delimiter of CSV input is ','
# [14:55:18] S3DistributionType set as FullyReplicated
# [14:55:18] 199364x30 matrix with 5980920 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2023-12-06:14:55:18:INFO] Determined delimiter of CSV input is ','
# [14:55:18] S3DistributionType set as FullyReplicated
# [14:55:18] 56962x30 matrix with 1708860 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [14:55:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [0]#011train-error:0.000647#011validation-error:0.000632
# [14:55:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=4
# [1]#011train-error:0.000497#011validation-error:0.000544
# [14:55:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=4
# [2]#011train-error:0.000497#011validation-error:0.000562
# [14:55:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [3]#011train-error:0.000497#011validation-error:0.000597
# [14:55:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [4]#011train-error:0.000512#011validation-error:0.000579
# [14:55:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [5]#011train-error:0.000497#011validation-error:0.000527
# [14:55:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [6]#011train-error:0.000446#011validation-error:0.000492
# [14:55:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=3
# [7]#011train-error:0.000421#011validation-error:0.000456
# [14:55:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [8]#011train-error:0.000436#011validation-error:0.000492
# [14:55:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=4
# [9]#011train-error:0.000431#011validation-error:0.000492
# [14:55:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [10]#011train-error:0.000426#011validation-error:0.000492
# [14:55:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [11]#011train-error:0.000416#011validation-error:0.000474
# [14:55:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [12]#011train-error:0.000421#011validation-error:0.000474
# [14:55:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=3
# [13]#011train-error:0.000441#011validation-error:0.000474
# [14:55:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=3
# [14]#011train-error:0.000431#011validation-error:0.000474
# [14:55:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=3
# [15]#011train-error:0.000431#011validation-error:0.000474
# [14:55:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=3
# [16]#011train-error:0.000431#011validation-error:0.000492
# [14:55:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 12 pruned nodes, max_depth=2
# [17]#011train-error:0.000431#011validation-error:0.000492
# [14:55:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=3
# [18]#011train-error:0.000441#011validation-error:0.000509
# [14:55:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=3
# [19]#011train-error:0.000441#011validation-error:0.000492
# [14:55:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [20]#011train-error:0.000441#011validation-error:0.000492
# [14:55:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [21]#011train-error:0.000441#011validation-error:0.000509
# [14:55:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=3
# [22]#011train-error:0.000436#011validation-error:0.000509
# [14:55:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=3
# [23]#011train-error:0.000421#011validation-error:0.000492
# [14:55:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=3
# [24]#011train-error:0.000416#011validation-error:0.000492
# [14:55:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 12 pruned nodes, max_depth=2
# [25]#011train-error:0.000416#011validation-error:0.000492
# [14:55:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [26]#011train-error:0.000396#011validation-error:0.000492
# [14:55:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [27]#011train-error:0.000396#011validation-error:0.000474
# [14:55:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=4
# [28]#011train-error:0.000396#011validation-error:0.000456
# [14:55:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=3
# [29]#011train-error:0.000401#011validation-error:0.000527
# [14:55:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=4
# [30]#011train-error:0.000401#011validation-error:0.000527
# [14:55:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [31]#011train-error:0.000406#011validation-error:0.000509
# [14:55:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [32]#011train-error:0.000381#011validation-error:0.000527
# [14:55:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [33]#011train-error:0.000386#011validation-error:0.000527
# [14:55:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [34]#011train-error:0.000376#011validation-error:0.000527
# [14:55:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=4
# [35]#011train-error:0.000371#011validation-error:0.000509
# [14:55:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [36]#011train-error:0.000366#011validation-error:0.000509
# [14:55:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [37]#011train-error:0.000346#011validation-error:0.000492
# [14:55:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [38]#011train-error:0.000351#011validation-error:0.000509
# [14:55:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [39]#011train-error:0.000356#011validation-error:0.000544
# [14:55:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [40]#011train-error:0.000346#011validation-error:0.000509
# [14:55:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [41]#011train-error:0.000346#011validation-error:0.000509
# [14:55:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=4
# [42]#011train-error:0.000356#011validation-error:0.000509
# [14:55:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=3
# [43]#011train-error:0.000351#011validation-error:0.000492
# [14:55:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [44]#011train-error:0.000351#011validation-error:0.000492
# [14:55:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [45]#011train-error:0.000341#011validation-error:0.000492
# [14:55:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [46]#011train-error:0.000356#011validation-error:0.000492
# [14:55:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [47]#011train-error:0.000361#011validation-error:0.000492
# [14:55:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [48]#011train-error:0.000361#011validation-error:0.000509
# [14:55:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [49]#011train-error:0.000356#011validation-error:0.000509
# [14:55:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [50]#011train-error:0.000356#011validation-error:0.000492
# [14:55:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [51]#011train-error:0.000351#011validation-error:0.000509
# [14:55:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [52]#011train-error:0.000351#011validation-error:0.000509
# [14:55:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [53]#011train-error:0.000341#011validation-error:0.000509
# [14:55:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=4
# [54]#011train-error:0.000336#011validation-error:0.000509
# [14:55:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [55]#011train-error:0.000336#011validation-error:0.000492
# [14:55:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=3
# [56]#011train-error:0.000336#011validation-error:0.000509
# [14:55:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [57]#011train-error:0.000336#011validation-error:0.000509
# [14:55:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [58]#011train-error:0.000336#011validation-error:0.000509
# [14:55:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [59]#011train-error:0.000336#011validation-error:0.000509
# [14:55:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [60]#011train-error:0.000331#011validation-error:0.000509
# [14:55:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [61]#011train-error:0.000331#011validation-error:0.000492
# [14:55:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [62]#011train-error:0.000326#011validation-error:0.000492
# [14:55:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [63]#011train-error:0.000321#011validation-error:0.000492
# [14:55:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [64]#011train-error:0.000326#011validation-error:0.000527
# [14:55:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [65]#011train-error:0.000306#011validation-error:0.000509
# [14:55:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [66]#011train-error:0.000296#011validation-error:0.000492
# [14:55:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [67]#011train-error:0.000311#011validation-error:0.000492
# [14:55:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [68]#011train-error:0.000306#011validation-error:0.000492
# [14:55:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [69]#011train-error:0.000311#011validation-error:0.000492
# [14:55:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [70]#011train-error:0.000306#011validation-error:0.000492
# [14:55:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [71]#011train-error:0.000296#011validation-error:0.000492
# [14:55:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [72]#011train-error:0.000301#011validation-error:0.000492
# [14:55:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [73]#011train-error:0.000296#011validation-error:0.000509
# [14:55:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [74]#011train-error:0.000296#011validation-error:0.000492
# [14:55:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [75]#011train-error:0.000296#011validation-error:0.000492
# [14:55:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=3
# [76]#011train-error:0.000296#011validation-error:0.000492
# [14:55:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 14 pruned nodes, max_depth=1
# [77]#011train-error:0.000291#011validation-error:0.000509
# [14:55:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [78]#011train-error:0.000286#011validation-error:0.000509
# [14:55:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [79]#011train-error:0.000286#011validation-error:0.000509
# [14:55:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [80]#011train-error:0.000291#011validation-error:0.000509
# [14:55:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [81]#011train-error:0.000286#011validation-error:0.000492
# [14:55:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [82]#011train-error:0.000291#011validation-error:0.000509
# [14:55:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [83]#011train-error:0.000286#011validation-error:0.000509
# [14:55:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [84]#011train-error:0.000291#011validation-error:0.000509
# [14:55:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [85]#011train-error:0.000291#011validation-error:0.000509
# [14:55:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [86]#011train-error:0.000286#011validation-error:0.000509
# [14:55:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [87]#011train-error:0.000291#011validation-error:0.000509
# [14:55:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [88]#011train-error:0.000291#011validation-error:0.000509
# [14:55:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [89]#011train-error:0.000291#011validation-error:0.000509
# [14:55:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [90]#011train-error:0.000286#011validation-error:0.000509
# [14:55:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [91]#011train-error:0.000286#011validation-error:0.000527
# [14:55:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [92]#011train-error:0.000286#011validation-error:0.000509
# [14:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [93]#011train-error:0.000286#011validation-error:0.000527
# [14:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [94]#011train-error:0.000276#011validation-error:0.000509
# [14:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [95]#011train-error:0.000276#011validation-error:0.000509
# [14:55:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [96]#011train-error:0.000271#011validation-error:0.000527
# [14:55:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [97]#011train-error:0.000271#011validation-error:0.000527
# [14:55:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [98]#011train-error:0.000271#011validation-error:0.000492
# [14:55:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [99]#011train-error:0.000276#011validation-error:0.000492
#
# 2023-12-06 14:56:11 Uploading - Uploading generated training model
# 2023-12-06 14:56:11 Completed - Training job completed
# Training seconds: 138
# Billable seconds: 138

# %% [markdown]
# ### Host XGBoost Model

# %% [markdown]
# Now we deploy the estimator to and endpoint.

# %%
xgb_predictor = xgb.deploy(
    initial_instance_count=1,
    instance_type='ml.m4.xlarge',
    endpoint_name='new-deployed-xgboost-fraud-prediction'  # Choose a unique endpoint name
)
# Out:
# INFO:sagemaker:Creating model with name: xgboost-2023-12-06-15-09-23-594
# INFO:sagemaker:Creating endpoint-config with name new-deployed-xgboost-fraud-prediction
# INFO:sagemaker:Creating endpoint with name new-deployed-xgboost-fraud-prediction
# ------!

# %% [markdown]
# ### Evaluate
#
# Now that we have a hosted endpoint running, we can make real-time predictions from our model very easily,
# simply by making an http POST request.  But first, we'll need to setup serializers and deserializers for passing our `test_data` NumPy arrays to the model behind the endpoint.

# %%
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import CSVDeserializer

xgb_predictor.content_type = 'text/csv'
xgb_predictor.serializer = CSVSerializer()
xgb_predictor.deserializer = CSVDeserializer()

# %% [markdown]
# Now, we'll use a simple function to:
# 1. Loop over our test dataset
# 1. Split it into mini-batches of rows
# 1. Convert those mini-batchs to CSV string payloads
# 1. Retrieve mini-batch predictions by invoking the XGBoost endpoint
# 1. Collect predictions and convert from the CSV output our model provides into a NumPy array

# %%
def predict(predictor, data, rows=500):
    predictions = []
    for i in range(0, data.shape[0], rows):
        subset = data.iloc[i:i + rows, 1:].values
        result = predictor.predict(subset)
        # Assuming your output is a list of predictions
        predictions.extend(result)

    # Flatten the list of predictions
    predictions_flat = [item for sublist in predictions for item in sublist]

    return np.array(predictions_flat)

# Assuming xgb_predictor has been properly initialized and the accept attribute is set.
# If not, set it using xgb_predictor.accept = 'text/csv'
xgb_predictor.accept = 'text/csv'
predictions = predict(xgb_predictor, test_data)
predictions = predictions.astype(float)

# %% [markdown]
# There are many ways to compare the performance of a machine learning model, but let's start by simply by comparing actual to predicted values. In this case, we're simply predicting whether the customer churned (1) or not (0), which produces a simple confusion matrix.

# %%
test_nonfrauds, test_frauds = test_data.groupby('Class').size()
print('Number of frauds: ', test_frauds)
print('Number of non-frauds: ', test_nonfrauds)
print('Percentage of fradulent data:', 100.*test_frauds/(test_frauds + test_nonfrauds))
# Out:
# Number of frauds:  54
# Number of non-frauds:  28427
# Percentage of fradulent data: 0.1896000842667041

# %%
# Truncate or pad rounded_predictions to match the length of test_data.iloc[:, 0]
rounded_predictions_fixed_length = rounded_predictions[:len(test_data.iloc[:, 0])]

# Create crosstab
pd.crosstab(index=test_data.iloc[:, 0], columns=rounded_predictions_fixed_length, rownames=['actual'], colnames=['predictions'])
# Out:
# predictions    0.0  1.0
# actual
# 0            28426    1
# 1               11   43

# %%
from sklearn.metrics import precision_recall_fscore_support

# Now, calculate precision and recall
results = precision_recall_fscore_support(test_data.iloc[:, 0], np.round(predictions))

print('precision:', round(results[0][1], 2))
print('recall:', round(results[1][1], 2))
# Out:
# precision: 0.98
# recall: 0.8

# %% [markdown]
# Note, due to randomized elements of the algorithm, you results may differ slightly.
#
# Of the 54 fraudsters, we've correctly predicted 40 of them (true positives). And, we incorrectly predicted 1 case of fraud (false positive). There are also 14 cases of fraud that the model classified as benign transaction (false negatives) - which can get really expensive.
#
# An important point here is that because of the np.round() function above we are using a simple threshold (or cutoff) of 0.5. Our predictions from xgboost come out as continuous values between 0 and 1 and we force them into the binary classes that we began with. So, we should consider adjusting this cutoff. That will almost certainly increase the number of false positives, but it can also be expected to increase the number of true positives and reduce the number of false negatives.
#
# To get a rough intuition here, let's look at the continuous values of our predictions.

# %%
plt.hist(predictions)
plt.show()

# %% [markdown]
# By varying the cutoff threshold, we can trade false positives for false negatives.

# %% [markdown]
# pd.crosstab(index=test_data.iloc[:, 0], columns=np.where(predictions > 0.04, 1, 0))

# %%
from sklearn.metrics import precision_recall_fscore_support

# Assuming test_data.iloc[:, 0] is the ground truth and predictions is a NumPy array
y_true = test_data.iloc[:, 0]
y_pred = np.where(predictions > 0.04, 1, 0)

# Print the lengths of y_true and y_pred
print("Length of y_true:", len(y_true))
print("Length of y_pred:", len(y_pred))

# Ensure that both arrays have the same length
if len(y_true) != len(y_pred):
    raise ValueError("Number of samples in y_true and y_pred must be the same.")

# Now, calculate precision and recall
results = precision_recall_fscore_support(y_true, y_pred, average='binary')
print('precision: ', round(results[0], 2))
print('recall: ', round(results[1], 2))
# Out:
# Length of y_true: 28481
# Length of y_pred: 28481
# precision:  0.78
# recall:  0.85

# %%
plt.hist(predictions)
plt.show()

# %% [markdown]
# ### Relative cost of errors
#
# Any practical binary classification problem is likely to produce a similarly sensitive cutoff.
# If we put an ML model into production, there are costs associated with the model erroneously assigning false positives and false negatives. Because the choice of the cutoff affects all four of these statistics, we need to consider the relative costs to the business for each of these four outcomes for each prediction.
#
# #### Assigning costs
#
# What are the costs for our problem fraud detection? The costs, of course, depend on the specific actions that the business takes. Let's make some assumptions here.
#
# First, assign the cost of \$0.00 to both the true negatives (correctly recognized benign transactions) and true positives (correctly recognized fraudulent transactions). Our model essentially correctly identified both situations. One can assign a benefit (i.e. negative cost) to correctly detected fraud, but we are not going to do this here.
#
# False negatives are the most problematic, because they represent a fraudulent transactions that slipped through our model. Based on some Internet research (see sources below), we assign a cost of \$450.00 for each one. This is the cost of false negatives.
#
# Finally, False positives are the genuine transactions that our model would block as fraud. This would result in an annoyed customer that might possibly close the credit card account and move to another bank. We assume that it costs a \$500.00 sign-on bonus to obtain a cr. card customer and that \5 percent of annoyed customers would defect.
#
# Source:
#
# https://www.creditcards.com/credit-card-news/credit-card-security-id-theft-fraud-statistics-1276.php
# https://wallethub.com/edu/cc/credit-debit-card-fraud-statistics/25725/

# %% [markdown]
# #### Finding the optimal cutoff
#
# It’s clear that false negatives are substantially more costly than false positives. We should be minimizing a cost function that looks like this:
#
# ```txt
# $450 * FN(C) + $0 * TN(C) + 0.05*$500 * FP(C) + $0 * TP(C)
# ```
#
# FN(C) means that the false negative percentage is a function of the cutoff, C, and similar for TN, FP, and TP.  We need to find the cutoff, C, where the result of the expression is smallest.
#
# A straightforward way to do this, is to simply run a simulation over a large number of possible cutoffs.  We test 100 possible values in the for loop below.

# %%
TN_cost = 0
TP_cost = 0
FP_cost = 0.05*500 #$cost of losing an annoyed customer (assuming 5% defection and $500 sign-on bonus)
FN_cost = 450 # $cost of of letting a fradulent transaction slip through

cutoffs = np.arange(0.01, 1, 0.01)
costs = []
for c in cutoffs:
    costs.append(np.sum(np.sum(np.array([[TN_cost, FP_cost], [FN_cost, TP_cost]]) * 
                               pd.crosstab(index=test_data.iloc[:, 0], 
                                           columns=np.where(predictions > c, 1, 0)))))

costs = np.array(costs)
plt.plot(cutoffs, costs)
plt.show()
print('Cost is minimized near a cutoff of:', cutoffs[np.argmin(costs)])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Cost is minimized near a cutoff of: 0.060000000000000005

# %% [markdown]
# ## Clean up
#
# We will leave the prediction endpoint running at the end of this notebook so we can handle incoming event streams. However, don't forget to delete the prediction endpoint when you're done. You can do that at the Amazon SageMaker console in the Endpoints page. Or you can run `xgb_predictor.delete_endpoint()`

# %%
#xgb_predictor.delete_endpoint()

# %% [markdown]
# ## Data Acknowledgements
#
# The dataset used to demonstrated the fraud detection solution has been collected and analysed during a research collaboration of Worldline and the Machine Learning Group (http://mlg.ulb.ac.be) of ULB (Université Libre de Bruxelles) on big data mining and fraud detection. More details on current and past projects on related topics are available on https://www.researchgate.net/project/Fraud-detection-5 and the page of the [DefeatFraud](https://mlg.ulb.ac.be/wordpress/portfolio_page/defeatfraud-assessment-and-validation-of-deep-feature-engineering-and-learning-solutions-for-fraud-detection/) project
# We cite the following works:
# * Andrea Dal Pozzolo, Olivier Caelen, Reid A. Johnson and Gianluca Bontempi. Calibrating Probability with Undersampling for Unbalanced Classification. In Symposium on Computational Intelligence and Data Mining (CIDM), IEEE, 2015
# * Dal Pozzolo, Andrea; Caelen, Olivier; Le Borgne, Yann-Ael; Waterschoot, Serge; Bontempi, Gianluca. Learned lessons in credit card fraud detection from a practitioner perspective, Expert systems with applications,41,10,4915-4928,2014, Pergamon
# * Dal Pozzolo, Andrea; Boracchi, Giacomo; Caelen, Olivier; Alippi, Cesare; Bontempi, Gianluca. Credit card fraud detection: a realistic modeling and a novel learning strategy, IEEE transactions on neural networks and learning systems,29,8,3784-3797,2018,IEEE
# * Dal Pozzolo, Andrea Adaptive Machine learning for credit card fraud detection ULB MLG PhD thesis (supervised by G. Bontempi)
# * Carcillo, Fabrizio; Dal Pozzolo, Andrea; Le Borgne, Yann-Aël; Caelen, Olivier; Mazzer, Yannis; Bontempi, Gianluca. Scarff: a scalable framework for streaming credit card fraud detection with Spark, Information fusion,41, 182-194,2018,Elsevier
# * Carcillo, Fabrizio; Le Borgne, Yann-Aël; Caelen, Olivier; Bontempi, Gianluca. Streaming active learning strategies for real-life credit card fraud detection: assessment and visualization, International Journal of Data Science and Analytics, 5,4,285-300,2018,Springer International Publishing
